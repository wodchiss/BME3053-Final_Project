# %%
import pandas as pd

df = pd.read_csv("/workspaces/BME3053-Final_Project/data/BBBC005_results_bray.csv")
print(df.shape)
print(df.columns)
df.head()
# Out:
# (9600, 23)
# Index(['Image_Count_DetectedNuclei', 'Image_FileName_CellBody',
#        'Image_FileName_Nuclei', 'Image_ImageQuality_Correlation_CellBody_10',
#        'Image_ImageQuality_Correlation_CellBody_2',
#        'Image_ImageQuality_Correlation_CellBody_20',
#        'Image_ImageQuality_Correlation_CellBody_40',
#        'Image_ImageQuality_Correlation_CellBody_5',
#        'Image_ImageQuality_Correlation_CellBody_80',
#        'Image_ImageQuality_Correlation_Nuclei_10',
#        'Image_ImageQuality_Correlation_Nuclei_2',
#        'Image_ImageQuality_Correlation_Nuclei_20',
#        'Image_ImageQuality_Correlation_Nuclei_40',
#        'Image_ImageQuality_Correlation_Nuclei_5',
#        'Image_ImageQuality_Correlation_Nuclei_80',
#        'Image_ImageQuality_FocusScore_CellBody',
#        'Image_ImageQuality_FocusScore_Nuclei',
#        'Image_ImageQuality_PowerLogLogSlope_CellBody',
#        'Image_ImageQuality_PowerLogLogSlope_Nuclei',
# ...

# %%
# Check for missing values
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Image_Count_DetectedNuclei                      0
# Image_FileName_CellBody                         0
# Image_FileName_Nuclei                           0
# Image_ImageQuality_Correlation_CellBody_10      0
# Image_ImageQuality_Correlation_CellBody_2       0
# Image_ImageQuality_Correlation_CellBody_20      0
# Image_ImageQuality_Correlation_CellBody_40      0
# Image_ImageQuality_Correlation_CellBody_5       0
# Image_ImageQuality_Correlation_CellBody_80      0
# Image_ImageQuality_Correlation_Nuclei_10        0
# Image_ImageQuality_Correlation_Nuclei_2         0
# Image_ImageQuality_Correlation_Nuclei_20        0
# Image_ImageQuality_Correlation_Nuclei_40        0
# Image_ImageQuality_Correlation_Nuclei_5         0
# Image_ImageQuality_Correlation_Nuclei_80        0
# Image_ImageQuality_FocusScore_CellBody          0
# Image_ImageQuality_FocusScore_Nuclei            0
# Image_ImageQuality_PowerLogLogSlope_CellBody    0
# ...

# %%
# Verify data types
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Image_Count_DetectedNuclei                        int64
# Image_FileName_CellBody                          object
# Image_FileName_Nuclei                            object
# Image_ImageQuality_Correlation_CellBody_10      float64
# Image_ImageQuality_Correlation_CellBody_2       float64
# Image_ImageQuality_Correlation_CellBody_20      float64
# Image_ImageQuality_Correlation_CellBody_40      float64
# Image_ImageQuality_Correlation_CellBody_5       float64
# Image_ImageQuality_Correlation_CellBody_80      float64
# Image_ImageQuality_Correlation_Nuclei_10        float64
# Image_ImageQuality_Correlation_Nuclei_2         float64
# Image_ImageQuality_Correlation_Nuclei_20        float64
# Image_ImageQuality_Correlation_Nuclei_40        float64
# Image_ImageQuality_Correlation_Nuclei_5         float64
# Image_ImageQuality_Correlation_Nuclei_80        float64
# Image_ImageQuality_FocusScore_CellBody          float64
# Image_ImageQuality_FocusScore_Nuclei            float64
# ...

# %%
# Check the column types
print(df.dtypes)
# Out:
# Image_Count_DetectedNuclei                        int64
# Image_FileName_CellBody                          object
# Image_FileName_Nuclei                            object
# Image_ImageQuality_Correlation_CellBody_10      float64
# Image_ImageQuality_Correlation_CellBody_2       float64
# Image_ImageQuality_Correlation_CellBody_20      float64
# Image_ImageQuality_Correlation_CellBody_40      float64
# Image_ImageQuality_Correlation_CellBody_5       float64
# Image_ImageQuality_Correlation_CellBody_80      float64
# Image_ImageQuality_Correlation_Nuclei_10        float64
# Image_ImageQuality_Correlation_Nuclei_2         float64
# Image_ImageQuality_Correlation_Nuclei_20        float64
# Image_ImageQuality_Correlation_Nuclei_40        float64
# Image_ImageQuality_Correlation_Nuclei_5         float64
# Image_ImageQuality_Correlation_Nuclei_80        float64
# Image_ImageQuality_FocusScore_CellBody          float64
# Image_ImageQuality_FocusScore_Nuclei            float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()

# Encode the categorical columns
df['encoded_Image_FileName_CellBody'] = label_encoder.fit_transform(df['Image_FileName_CellBody'])
df['encoded_Image_FileName_Nuclei'] = label_encoder.fit_transform(df['Image_FileName_Nuclei'])

# Verify the encoding
print(df[['Image_FileName_CellBody', 'encoded_Image_FileName_CellBody']].head())
print(df[['Image_FileName_Nuclei', 'encoded_Image_FileName_Nuclei']].head())
# Out:
#              Image_FileName_CellBody  encoded_Image_FileName_CellBody
# 0  SIMCEPImages_A01_C1_F1_s15_w1.TIF                               14
# 1  SIMCEPImages_A01_C1_F1_s22_w1.TIF                               21
# 2  SIMCEPImages_A01_C1_F1_s05_w1.TIF                                4
# 3  SIMCEPImages_A01_C1_F1_s12_w1.TIF                               11
# 4  SIMCEPImages_A01_C1_F1_s11_w1.TIF                               10
#                Image_FileName_Nuclei  encoded_Image_FileName_Nuclei
# 0  SIMCEPImages_A01_C1_F1_s15_w2.TIF                             14
# 1  SIMCEPImages_A01_C1_F1_s22_w2.TIF                             21
# 2  SIMCEPImages_A01_C1_F1_s05_w2.TIF                              4
# 3  SIMCEPImages_A01_C1_F1_s12_w2.TIF                             11
# 4  SIMCEPImages_A01_C1_F1_s11_w2.TIF                             10

# %%
# Features (X) and Target (y)
X = df.drop(columns=['Image_Count_DetectedNuclei'])  # drop the target column
y = df['Image_Count_DetectedNuclei']  # the target

# %%
# Select only numeric columns from X (exclude categorical columns like file names)
X_numeric = X.select_dtypes(include=['float64', 'int64'])

# Initialize the scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Apply scaling to the numeric columns
X_scaled = scaler.fit_transform(X_numeric)

# Convert the scaled data back to a DataFrame for better readability (optional)
X_scaled_df = pd.DataFrame(X_scaled, columns=X_numeric.columns)

# Check the first few rows of the scaled data
print(X_scaled_df.head())
# Out:
#    Image_ImageQuality_Correlation_CellBody_10  \
# 0                                   -0.629360
# 1                                   -0.748527
# 2                                   -1.236145
# 3                                   -0.467221
# 4                                   -1.221168
#
#    Image_ImageQuality_Correlation_CellBody_2  \
# 0                                   0.485303
# 1                                   0.510494
# 2                                  -0.248494
# 3                                   0.100075
# 4                                  -0.643758
#
#    Image_ImageQuality_Correlation_CellBody_20  \
# 0                                   -0.583291
# 1                                   -0.689332
# 2                                   -1.284323
# 3                                    0.622062
# 4                                   -0.742202
#
#    Image_ImageQuality_Correlation_CellBody_40  \
# 0                                   -0.439853
# ...
